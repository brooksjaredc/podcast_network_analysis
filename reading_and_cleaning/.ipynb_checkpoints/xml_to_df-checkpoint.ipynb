# %%
import xml.etree.ElementTree as ET
import numpy as np
import pandas as pd
import re
import networkx as nx
import datetime as dt
import time

from cleaning_functions import *
from cleaners import *

# %matplotlib notebook

# %%
df = pd.read_csv('cleaned_podcasts.csv', sep='\t', index_col=0)
df
# Out:
#                       date  duration episode                  guests  \
# 0      2018-03-20 22:29:51     10603    1094            Brian Redban
# 1      2018-03-19 23:20:58     11990    1093           Owen Benjamin
# 2      2018-03-19 23:20:58     11990    1093            Kurt Metzger
# 3      2018-03-15 00:26:37      7725    1092       Mary Lynn Rajskub
# 4      2018-03-14 23:39:03      9406    1091         Daniele Bolelli
# 5      2018-03-13 23:22:42     11795    1090          Andrew Santino
# 6      2018-03-08 02:07:37     13856    1089             John Dudley
# 7      2018-03-07 03:06:07     11805    1088            Bryan Callen
# 8      2018-03-05 23:37:15     10793    1087        Sturgill Simpson
# 9      2018-03-01 00:54:02     11608    1086           Rory Albanese
# 10     2018-02-28 00:22:04     11430    1085           Kyle Kulinski
# 11     2018-02-26 23:30:43      7639    1084          Douglas Murray
# 12     2018-02-23 02:48:27      6444    1083              Dom Irrera
# 13     2018-02-22 00:24:19      9387    1082        Greg Fitzsimmons
# 14     2018-02-20 22:27:16     10909    1081          Bret Weinstein
# 15     2018-02-20 22:27:16     10909    1081          Heather Heying
# 16     2018-02-19 22:12:17      7676    1080           David Goggins
# 17     2018-02-15 23:55:15     11301    1079        Tony Hinchcliffe
# 18     2018-02-14 02:51:28     10755    1078              Jimmy Dore
# 19     2018-02-12 22:42:57      9753    1077             Johann Hari
# 20     2018-02-09 22:04:38      5210    1076             Phil Demers
# 21     2018-02-08 23:58:39     13000    1075         Duncan Trussell
# 22     2018-02-06 23:27:34      9978    1074           Cameron Hanes
# 23     2018-02-04 20:37:17      8359    1073           Steven Pinker
# 24     2018-02-01 23:30:19     11723    1072               Joey Diaz
# 25     2018-01-31 00:39:30      9288    1071          Steven Crowder
# 26     2018-01-31 00:39:30      9288    1071            Notgay Jared
# 27     2018-01-30 21:22:02      9363    1070         Jordan Peterson
# 28     2018-01-29 23:54:13      9303    1069          Ben Greenfield
# 29     2018-01-24 22:05:09      9218    1068         Michael Shermer
# ...                    ...       ...     ...                     ...
# 25934  2017-10-16 04:57:29      1975     NaN        Francine Wheeler
# 25935  2017-10-11 04:57:11      2071     NaN           Shaka Senghor
# 25936  2017-10-09 04:57:39      2127     NaN            Phil Jackson
# 25937  2017-10-04 04:57:38      2030     NaN          Michael Singer
# 25938  2017-10-02 04:57:23      1536     NaN        Shirley MacLaine
# 25939  2017-09-27 04:57:31      1947     NaN             Nate Berkus
# 25940  2017-09-25 04:57:32      2019     NaN             Nate Berkus
# 25941  2017-09-20 04:57:41      1915     NaN  Sister Joan Chittister
# 25942  2017-09-18 04:57:09      1565     NaN         Don Miguel Ruiz
# 25943  2017-09-14 04:57:49      2077     NaN          Howard Schultz
# 25944  2017-09-11 04:57:20      2307     NaN     Pastor A.R. Bernard
# 25945  2017-09-07 04:57:38      1842     NaN          Cookie Johnson
# 25946  2017-09-04 04:57:05      2048     NaN  President Jimmy Carter
# 25947  2017-08-30 04:57:34      1721     NaN            Rainn Wilson
# 25948  2017-08-28 04:57:28      2341     NaN             Mitch Albom
# 25949  2017-08-23 04:57:53      2037     NaN       Alanis Morissette
# 25950  2017-08-16 04:57:26      1832     NaN              India Arie
# 25951  2017-08-14 04:57:35      1825     NaN              India Arie
# 25952  2017-08-11 04:57:15      2028     NaN             Joel Osteen
# 25953  2017-08-10 18:57:59      2095     NaN           Deepak Chopra
# 25954  2017-08-10 09:57:48      1586     NaN            Paulo Coelho
# 25955  2017-08-10 03:57:48      1828     NaN            Paulo Coelho
# 25956  2017-08-09 19:00:01      1853     NaN      Arianna Huffington
# 25957  2017-08-09 07:00:08      2197     NaN            Tracy Morgan
# 25958  2017-08-08 19:00:20      1890     NaN           Glennon Doyle
# 25959  2017-08-08 10:00:55      2097     NaN          Iyanla Vanzant
# 25960  2017-08-08 04:00:00      2034     NaN          Iyanla Vanzant
# 25961  2017-08-07 19:00:54      2421     NaN         Sheryl Sandberg
# 25962  2017-08-07 10:00:54      1717     NaN             Brené Brown
# 25963  2017-08-07 04:00:23      2140     NaN             Brené Brown
#
#                hosts                          podcast  \
# 0          Joe Rogan         The Joe Rogan Experience
# 1          Joe Rogan         The Joe Rogan Experience
# 2          Joe Rogan         The Joe Rogan Experience
# 3          Joe Rogan         The Joe Rogan Experience
# 4          Joe Rogan         The Joe Rogan Experience
# 5          Joe Rogan         The Joe Rogan Experience
# 6          Joe Rogan         The Joe Rogan Experience
# 7          Joe Rogan         The Joe Rogan Experience
# 8          Joe Rogan         The Joe Rogan Experience
# 9          Joe Rogan         The Joe Rogan Experience
# 10         Joe Rogan         The Joe Rogan Experience
# 11         Joe Rogan         The Joe Rogan Experience
# 12         Joe Rogan         The Joe Rogan Experience
# 13         Joe Rogan         The Joe Rogan Experience
# 14         Joe Rogan         The Joe Rogan Experience
# 15         Joe Rogan         The Joe Rogan Experience
# 16         Joe Rogan         The Joe Rogan Experience
# 17         Joe Rogan         The Joe Rogan Experience
# 18         Joe Rogan         The Joe Rogan Experience
# 19         Joe Rogan         The Joe Rogan Experience
# 20         Joe Rogan         The Joe Rogan Experience
# 21         Joe Rogan         The Joe Rogan Experience
# 22         Joe Rogan         The Joe Rogan Experience
# 23         Joe Rogan         The Joe Rogan Experience
# 24         Joe Rogan         The Joe Rogan Experience
# 25         Joe Rogan         The Joe Rogan Experience
# 26         Joe Rogan         The Joe Rogan Experience
# 27         Joe Rogan         The Joe Rogan Experience
# 28         Joe Rogan         The Joe Rogan Experience
# 29         Joe Rogan         The Joe Rogan Experience
# ...              ...                              ...
# 25934  Oprah Winfrey  Oprah’s SuperSoul Conversations
# 25935  Oprah Winfrey  Oprah’s SuperSoul Conversations
# 25936  Oprah Winfrey  Oprah’s SuperSoul Conversations
# 25937  Oprah Winfrey  Oprah’s SuperSoul Conversations
# 25938  Oprah Winfrey  Oprah’s SuperSoul Conversations
# 25939  Oprah Winfrey  Oprah’s SuperSoul Conversations
# 25940  Oprah Winfrey  Oprah’s SuperSoul Conversations
# 25941  Oprah Winfrey  Oprah’s SuperSoul Conversations
# 25942  Oprah Winfrey  Oprah’s SuperSoul Conversations
# 25943  Oprah Winfrey  Oprah’s SuperSoul Conversations
# 25944  Oprah Winfrey  Oprah’s SuperSoul Conversations
# 25945  Oprah Winfrey  Oprah’s SuperSoul Conversations
# 25946  Oprah Winfrey  Oprah’s SuperSoul Conversations
# 25947  Oprah Winfrey  Oprah’s SuperSoul Conversations
# 25948  Oprah Winfrey  Oprah’s SuperSoul Conversations
# 25949  Oprah Winfrey  Oprah’s SuperSoul Conversations
# 25950  Oprah Winfrey  Oprah’s SuperSoul Conversations
# 25951  Oprah Winfrey  Oprah’s SuperSoul Conversations
# 25952  Oprah Winfrey  Oprah’s SuperSoul Conversations
# 25953  Oprah Winfrey  Oprah’s SuperSoul Conversations
# 25954  Oprah Winfrey  Oprah’s SuperSoul Conversations
# 25955  Oprah Winfrey  Oprah’s SuperSoul Conversations
# 25956  Oprah Winfrey  Oprah’s SuperSoul Conversations
# 25957  Oprah Winfrey  Oprah’s SuperSoul Conversations
# 25958  Oprah Winfrey  Oprah’s SuperSoul Conversations
# 25959  Oprah Winfrey  Oprah’s SuperSoul Conversations
# 25960  Oprah Winfrey  Oprah’s SuperSoul Conversations
# 25961  Oprah Winfrey  Oprah’s SuperSoul Conversations
# 25962  Oprah Winfrey  Oprah’s SuperSoul Conversations
# 25963  Oprah Winfrey  Oprah’s SuperSoul Conversations
#
#                                                    title
# 0                                   #1094 - Brian Redban
# 1                   #1093 - Owen Benjamin & Kurt Metzger
# 2                   #1093 - Owen Benjamin & Kurt Metzger
# 3                              #1092 - Mary Lynn Rajskub
# 4                                #1091 - Daniele Bolelli
# 5                                 #1090 - Andrew Santino
# 6                                    #1089 - John Dudley
# 7                                   #1088 - Bryan Callen
# 8                               #1087 - Sturgill Simpson
# 9                                  #1086 - Rory Albanese
# 10                                 #1085 - Kyle Kulinski
# 11                                #1084 - Douglas Murray
# 12                                    #1083 - Dom Irrera
# 13                              #1082 - Greg Fitzsimmons
# 14               #1081 - Bret Weinstein & Heather Heying
# 15               #1081 - Bret Weinstein & Heather Heying
# 16                                 #1080 - David Goggins
# 17                              #1079 - Tony Hinchcliffe
# 18                                    #1078 - Jimmy Dore
# 19                                   #1077 - Johann Hari
# 20                                   #1076 - Phil Demers
# 21                               #1075 - Duncan Trussell
# 22                                 #1074 - Cameron Hanes
# 23                                 #1073 - Steven Pinker
# 24                                     #1072 - Joey Diaz
# 25                 #1071 - Steven Crowder & NotGay Jared
# 26                 #1071 - Steven Crowder & NotGay Jared
# 27                               #1070 - Jordan Peterson
# 28                                #1069 - Ben Greenfield
# 29                               #1068 - Michael Shermer
# ...                                                  ...
# 25934        David and Francine Wheeler: Life After Loss
# 25935  Shaka Senghor: Prison Taught Him the Power of ...
# 25936                  Phil Jackson: The Soul of Success
# 25937  Michael Singer: Free Yourself from Negative Th...
# 25938               Shirley MacLaine: A Legendary Seeker
# 25939                   Nate Berkus: Surviving the Storm
# 25940                Nate Berkus: Design for Your Spirit
# 25941  Sister Joan Chittister: Two Words That Can Cha...
# 25942  Don Miguel Ruiz: Find Freedom, Happiness and Love
# 25943  Howard Schultz: Pouring Your Heart into Your B...
# 25944  Pastor A.R. Bernard: Four Things Women Want fr...
# 25945  Cookie Johnson: Why She Stood by Magic Through...
# 25946  President Jimmy Carter: His Prayers from Insid...
# 25947              Rainn Wilson: Why Are We Really Here?
# 25948  Mitch Albom: The Dying Know the Secrets to a G...
# 25949  Alanis Morissette: Is Happiness Temporary? (Ma...
# 25950   India.Arie, Part 2: Refresh Your Spiritual Roots
# 25951  India.Arie, Part 1: Why She Walked Away from M...
# 25952  Joel Osteen: The Two Powerful Words That Can C...
# 25953                      Deepak Chopra: Meditation 101
# 25954  Paulo Coelho, Part 2: Your Journey of Self-Dis...
# 25955  Paulo Coelho, Part 1: What If the Universe Con...
# 25956  Arianna Huffington: What Will Be Your Spiritua...
# 25957  Tracy Morgan: What His Near-Death Experience T...
# 25958  Glennon Doyle: The Power of Embracing Your Mes...
# 25959        Iyanla Vanzant, Part 2: Back from the Brink
# 25960  Iyanla Vanzant, Part 1: Put the Pieces Back To...
# 25961  Sheryl Sandberg: How to Build Resilience and F...
# 25962      Brené Brown Part 2: Living with a Whole Heart
# 25963                 Brené Brown Part 1: Daring Greatly
#
# [25964 rows x 7 columns]

# %%
split_hosts = splitDataFrameList(df, 'hosts', ', ')
split_hosts

G1 = nx.from_pandas_dataframe(split_hosts, 'guests', 'hosts', edge_attr=['date', 'duration', 'podcast'], create_using=nx.MultiDiGraph())

# %%
G1.edges(data=True)
#nx.average_shortest_path_length(G1)
#nx.eccentricity(G1,'Joe Rogan')
nx.shortest_path_length(G1, "Skepticism")
#nx.shortest_path(G1, 'President Barack Obama', 'Dan Harmon')
#len(G1.edges())
# Out:
# {'Al Madrigal': 3,
#  'Alison Rosen': 3,
#  'Andy Cohen': 5,
#  'Anna Faris': 4,
#  'April Macie': 3,
#  'Ari Shaffir': 3,
#  'Aubrey Marcus': 3,
#  'Bert Kreischer': 3,
#  'Big Jay Oakerson': 4,
#  'Bill Burr': 3,
#  'Bill Maher': 5,
#  'Bill Simmons': 3,
#  'Bob Forrest': 4,
#  'Brandt Tobler': 4,
#  'Brendan Schaub': 3,
#  'Brendon Walsh': 3,
#  'Brian Redban': 3,
#  'Brian Rose': 4,
#  'Brody Stevens': 3,
#  'Bryan Callen': 3,
#  'Cameron Esposito': 3,
#  'Casey Wilson': 5,
#  'Cheryl Strayed': 7,
#  'Chris Grosso': 4,
#  'Chris Hardwick': 3,
#  'Chris Mancini': 4,
#  'Chris Ryan': 4,
#  'Chris Vernon': 4,
#  'Christina Pazsitzky': 3,
#  'Christopher Ryan': 3,
#  'Conner Moore': 3,
#  'Cory Allen': 2,
#  'Dan Harmon': 3,
#  'Dan Harris': 5,
#  'Dan Savage': 4,
#  'Dan St. Germain': 4,
#  'Danielle Schneider': 5,
#  'Dave Asprey': 5,
#  'Dave Rubin': 5,
#  'Dave Shumka': 4,
#  'Dave Smith': 4,
#  'David Axelrod': 6,
#  'Dax Shepard': 5,
#  'Derek Colanduno': 6,
#  'Dom Irrera': 4,
#  'Doug Benson': 3,
#  'Doug Stanhope': 4,
#  'Dr. Drew': 4,
#  'Duncan Trussell': 2,
#  'Echo Charles': 5,
#  'Emily V. Gordon': 3,
#  'Ethan Klein': 5,
#  'Ezra Klein': 5,
#  'Grace Helbig': 3,
#  'Graham Clark': 4,
#  'Graham Elwood': 4,
#  'Greg Fitzsimmons': 3,
#  'Hannibal Buress': 4,
#  'Hayes Davenport': 5,
#  'Howard Kremer': 4,
#  'Iliza Shlesinger': 4,
#  'Jack Ferry': 3,
#  'Jack O’Brien': 4,
#  'James Altucher': 4,
#  'Jason Gots': 4,
#  'Jason Mantzoukas': 4,
#  'Jason Sklar': 3,
#  'Jay Larson': 3,
#  'Jay Mohr': 5,
#  'Jayson Thibault': 4,
#  'Jeremy Carter': 4,
#  'Jesse Thorn': 3,
#  'Jessie Maltin': 4,
#  'Jim Norton': 4,
#  'Jimmy Pardo': 4,
#  'Jocko Willink': 5,
#  'Joe Rogan': 3,
#  'Joey Diaz': 4,
#  'John Gonzalez': 4,
#  'John Roy': 3,
#  'Johnny Pemberton': 3,
#  'Jon Gabrus': 4,
#  'Jonathan Tjarks': 4,
#  'Jonathan Van Ness': 4,
#  'Jordan Morris': 4,
#  'Josh Horowitz': 4,
#  'Julia Galef': 5,
#  'Julian McCullough': 4,
#  'Juliet Litman': 4,
#  'June Diane Raphael': 4,
#  'Justin Verrier': 4,
#  'Katie Couric': 5,
#  'Kevin O’Connor': 4,
#  'Kevin Pereira': 4,
#  'Kevin Smith': 4,
#  'Kulap Vilaysack': 4,
#  'Kumail Nanjiani': 3,
#  'Kurt Braunohler': 3,
#  'Kurt Metzger': 4,
#  'Leonard Maltin': 4,
#  'Lewis Howes': 5,
#  'Luis J. Gomez': 4,
#  'Marc Maron': 4,
#  'Mark McConville': 4,
#  'Matt Besser': 5,
#  'Matt Fulchiron': 4,
#  'Matt Gourley': 4,
#  'Matt Serra': 4,
#  'Matthew Cole Weiss': 4,
#  'Meghna Chakrabarti': 4,
#  'Michael Rapaport': 4,
#  'Michelle Visage': 5,
#  'Mike Mitchell': 4,
#  'Moshe Kasher': 4,
#  'Neal Brennan': 4,
#  'Neil deGrasse Tyson': 4,
#  'Nick Wiger': 4,
#  'Ophira Eisenberg': 4,
#  'Oprah Winfrey': 6,
#  'Paul F. Tompkins': 4,
#  'Paul Scheer': 4,
#  'Pete Holmes': 2,
#  'Raghu Markus': 1,
#  'Randy Liedtke': 3,
#  'Randy Sklar': 3,
#  'Rhea Butcher': 3,
#  'Robynn McCarthy': 6,
#  'RuPaul': 5,
#  'Russell Brand': 6,
#  'Ryan Sickler': 3,
#  'Sam Harris': 5,
#  'Sam Jones': 3,
#  'Sam Tripoli': 4,
#  'Scott Aukerman': 4,
#  'Scott Mosier': 4,
#  'Sean Clements': 5,
#  'Sean Donnelly': 4,
#  'Shane Dawson': 4,
#  'Shane Mauss': 3,
#  'Sherrod Small': 4,
#  'Skepticism': 0,
#  'Snoop Dogg': 4,
#  'Stefan Molyneux': 5,
#  'Steve Agee': 3,
#  'Steve Almond': 7,
#  'Steve Rannazzisi': 4,
#  'Steve Simeone': 4,
#  'Steven Crowder': 4,
#  'Tait Fletcher': 4,
#  'Theo Von': 4,
#  'Thomas Thakkar': 4,
#  'Tim Ferriss': 4,
#  'Todd Barry': 3,
#  'Todd Glass': 3,
#  'Tom Rhodes': 3,
#  'Tom Segura': 3,
#  'Tommy McNamara': 4,
#  'Tony Hinchcliffe': 3,
#  'Zach Leary': 3}

# %%
raghu_markus = 'rss_files/raghu_markus.xml'

def clean_raghu_markus(raghu_markus):

    raghu_markus = xml_to_df(raghu_markus)
        
    date_parser('\s\-0000', raghu_markus)
    
    raghu_markus['guests'] = raghu_markus.title.str.extract(r'Ep. \d+ (?:-|–) ([\w\s\.\,\'\`\’\&\"\-\‘\/]+)',expand=True)
    
    guest_split(' Part', raghu_markus)
    guest_split(' Returns', raghu_markus)
    guest_split(' Live', raghu_markus)
    guest_split(' Goes', raghu_markus)
    guest_split(' Explores', raghu_markus)
    guest_split("'s ", raghu_markus)
    guest_split_last('with ', raghu_markus)
    guest_split_last('w/ ', raghu_markus)
    guest_split_last('Clearly ', raghu_markus)
    guest_split_last('Founder ', raghu_markus)
    
    replace('Anne and Joan Watts', 'Anne Watts and Joan Watts', raghu_markus)
    replace('It', np.nan, raghu_markus)
    replace('2018', np.nan, raghu_markus)
    replace("Teal Swan's Vision", "Teal Swan", raghu_markus)
    
    
    raghu_markus = raghu_markus[raghu_markus.guests.str.contains(r' of ') == False]
    raghu_markus = raghu_markus[raghu_markus.guests.str.contains(r' Of ') == False]
    raghu_markus = raghu_markus[raghu_markus.guests.str.contains(r' the ') == False]
    raghu_markus = raghu_markus[raghu_markus.guests.str.contains(r'The ') == False]
    raghu_markus = raghu_markus[raghu_markus.guests.str.contains(r' To ') == False]
    raghu_markus = raghu_markus[raghu_markus.guests.str.contains(r' Our ') == False]
    raghu_markus = raghu_markus[raghu_markus.guests.str.contains(r' better ') == False]
    raghu_markus = raghu_markus[raghu_markus.guests.str.contains(r' Into ') == False]
    raghu_markus = raghu_markus[raghu_markus.guests.str.contains(r' is ') == False]
    raghu_markus = raghu_markus[raghu_markus.guests.str.contains(r' with ') == False]
    raghu_markus = raghu_markus[raghu_markus.guests.str.contains(r' Your ') == False]
    raghu_markus = raghu_markus[raghu_markus.guests.str.contains(r' in ') == False]
    raghu_markus = raghu_markus[raghu_markus.guests.str.contains(r' it ') == False]
    raghu_markus = raghu_markus[raghu_markus.guests.str.contains(r' Days') == False]
    raghu_markus = raghu_markus[raghu_markus.guests.str.contains(r' than ') == False]
    raghu_markus = raghu_markus[raghu_markus.guests.str.contains(r' as ') == False]
    raghu_markus = raghu_markus[raghu_markus.guests.str.contains(r'Politics') == False]
    raghu_markus = raghu_markus[raghu_markus.guests.str.contains(r'Rascals') == False]
    raghu_markus = raghu_markus[raghu_markus.guests.str.contains(r'Yourself') == False]
    raghu_markus = raghu_markus[raghu_markus.guests.str.contains(r'Musings') == False]
    raghu_markus = raghu_markus[raghu_markus.guests.str.contains(r'World') == False]
    raghu_markus = raghu_markus[raghu_markus.guests.str.contains(r'Attention') == False]
    raghu_markus = raghu_markus[raghu_markus.guests.str.contains(r'Glories') == False]
    raghu_markus = raghu_markus[raghu_markus.guests.str.contains(r'After') == False]
    raghu_markus = raghu_markus[raghu_markus.guests.str.contains(r'Suffering') == False]
    raghu_markus = raghu_markus[raghu_markus.guests.str.contains(r'Digital') == False]
    raghu_markus = raghu_markus[raghu_markus.guests.str.contains(r'Close') == False]
    raghu_markus = raghu_markus[raghu_markus.guests.str.contains(r'Teachers') == False]
    raghu_markus = raghu_markus[raghu_markus.guests.str.contains(r'India') == False]
    raghu_markus = raghu_markus[raghu_markus.guests.str.contains(r'Irregular') == False]
    raghu_markus = raghu_markus[raghu_markus.guests.str.contains(r'India') == False]
    raghu_markus = raghu_markus[raghu_markus.guests.str.contains(r'Spontaneous') == False]
    raghu_markus = raghu_markus[raghu_markus.guests.str.contains(r'Brain') == False]
    raghu_markus = raghu_markus[raghu_markus.guests.str.contains(r'Within') == False]
    raghu_markus = raghu_markus[raghu_markus.guests.str.contains(r'Happiness') == False]
    raghu_markus = raghu_markus[raghu_markus.guests.str.contains(r'Unconscious') == False]
    raghu_markus = raghu_markus[raghu_markus.guests.str.contains(r'Conscious') == False]
    raghu_markus = raghu_markus[raghu_markus.guests.str.contains(r'Street') == False]
    raghu_markus = raghu_markus[raghu_markus.guests.str.contains(r'Giant') == False]
    raghu_markus = raghu_markus[raghu_markus.guests.str.contains(r'Matters') == False]
    raghu_markus = raghu_markus[raghu_markus.guests.str.contains(r'True') == False]
    raghu_markus = raghu_markus[raghu_markus.guests.str.contains(r'Mindfulness') == False]
    raghu_markus = raghu_markus[raghu_markus.guests.str.contains(r' his ') == False]
    raghu_markus = raghu_markus[raghu_markus.guests.str.contains(r' to ') == False]
    raghu_markus = raghu_markus[raghu_markus.guests.str.contains(r' for ') == False]
    raghu_markus = raghu_markus[raghu_markus.guests.str.contains(r'Imagination') == False]
    raghu_markus = raghu_markus[raghu_markus.guests.str.contains(r'Shock') == False]
    raghu_markus = raghu_markus[raghu_markus.guests.str.contains(r'Power') == False]
    raghu_markus = raghu_markus[raghu_markus.guests.str.contains(r'Thought') == False]
    raghu_markus = raghu_markus[raghu_markus.guests.str.contains(r' A ') == False]
    raghu_markus = raghu_markus[raghu_markus.guests.str.contains(r'G-d') == False]
    raghu_markus = raghu_markus[raghu_markus.guests.str.contains(r'Mode') == False]
    raghu_markus = raghu_markus[raghu_markus.guests.str.contains(r'Buddhism') == False]
    raghu_markus = raghu_markus[raghu_markus.guests.str.contains(r'Abundance') == False]
    raghu_markus = raghu_markus[raghu_markus.guests.str.contains(r'Quantum') == False]
    raghu_markus = raghu_markus[raghu_markus.guests.str.contains(r'Tour ') == False]
    raghu_markus = raghu_markus[raghu_markus.guests.str.contains(r'Presence') == False]
    raghu_markus = raghu_markus[raghu_markus.guests.str.contains(r'Mental') == False]
    raghu_markus = raghu_markus[raghu_markus.guests.str.contains(r'Home') == False]
    raghu_markus = raghu_markus[raghu_markus.guests.str.contains(r'EUDAIMONIA') == False]
    raghu_markus = raghu_markus[raghu_markus.guests.str.contains(r'There') == False]
    raghu_markus = raghu_markus[raghu_markus.guests.str.contains(r'Love') == False]
    raghu_markus = raghu_markus[raghu_markus.guests.str.contains(r'One ') == False]
    
    raghu_markus = raghu_markus[pd.notnull(raghu_markus['guests'])]
    raghu_markus = splitDataFrameList(raghu_markus, 'guests', ', and ')
    raghu_markus = splitDataFrameList(raghu_markus, 'guests', ', & ')
    raghu_markus = splitDataFrameList(raghu_markus, 'guests', ', ')
    raghu_markus = splitDataFrameList(raghu_markus, 'guests', ',')
    raghu_markus = splitDataFrameList(raghu_markus, 'guests', ' & ')
    raghu_markus = splitDataFrameList(raghu_markus, 'guests', ' And ')
    raghu_markus = splitDataFrameList(raghu_markus, 'guests', ' and ')
    
    raghu_markus = raghu_markus[raghu_markus.guests.str.contains(r'MLK') == False]

    raghu_markus['guests'] = [g.rstrip() for g in raghu_markus['guests']]
    
    return raghu_markus

clean_raghu_markus(raghu_markus)[50:100]
# Out:
#                   date  duration                       guests  \
# 50 2017-03-24 12:15:32      3473                     JP Sears
# 51 2017-03-17 14:11:45      3481                  Dakota Wint
# 52 2017-03-17 14:11:45      3481                   Koi Fresco
# 53 2017-03-06 07:08:46      4223               Dr. Paul Ekman
# 54 2017-02-10 14:48:48      3784               Lama Surya Das
# 55 2017-02-03 13:54:48      3086                  Mona Haydar
# 56 2017-01-27 14:12:37      3554                 Nancy Colier
# 57 2017-01-18 05:57:27      3913                 David Silver
# 58 2017-01-05 19:16:26      4343        Lama Tsultrim Allione
# 59 2016-12-20 16:09:49      4050                     Rob Bell
# 60 2016-12-09 04:09:15      3129      Chris "Bash" Bashinelli
# 61 2016-12-02 05:36:30      3412  Reverend Alexander MacPhail
# 62 2016-11-18 19:21:27      4586                        Mooji
# 63 2016-11-11 16:26:12      3981                   Jared Levy
# 64 2016-11-11 16:26:12      3981              Martin Winiecki
# 65 2016-11-04 16:54:09      3485               Sacred Science
# 66 2016-10-21 14:39:44      3853               David Nichtern
# 67 2016-10-10 22:32:25      3205                Kenny Ausubel
# 68 2016-10-05 14:06:40      3796              Larry Brilliant
# 69 2016-09-26 17:08:17      3633                Judith Orloff
# 70 2016-09-15 16:24:57      4370                   Dan Harmon
# 71 2016-09-15 16:24:57      4370              Duncan Trussell
# 72 2016-08-11 16:28:26      3897                 Vincent Horn
# 73 2016-07-13 15:47:30      3040                  Trevor Hall
# 74 2016-07-13 15:47:30      3040                  Mother Kali
# 75 2016-06-23 19:58:01      3539                 Gil Fronsdal
# 76 2016-06-02 18:27:42      3203                 Polarization
# 77 2016-05-03 02:39:29      3055              Frank Ostaseski
# 78 2016-04-19 18:42:32      3078               Lisa Wimberger
# 79 2016-04-07 19:26:46      3465                   Dream Yoga
# 80 2016-03-29 21:04:49      2984         Koshin Paley Ellison
# 81 2016-03-21 21:20:16      3742                  Rick Doblin
# 82 2016-03-05 17:14:01      3455              Jake Sasseville
# 83 2016-02-23 15:30:42      3871                   James Doty
# 84 2016-01-20 22:31:40      3934              Kiley Jon Clark
# 85 2016-01-12 16:13:47      4608                   Reggie Ray
# 86 2015-12-25 03:05:19      3306             Dr. Linda Bender
# 87 2015-12-18 16:51:42      3769                   Rabbi Rami
# 88 2015-11-28 06:24:31      2783           Roshi Joan Halifax
# 89 2015-11-28 06:24:31      2783
# 90 2015-11-17 20:32:32      4262                      Seekers
# 91 2015-11-17 20:32:32      4262                    Smugglers
# 92 2015-10-15 16:10:17      4424                Jungle Safari
# 93 2015-10-01 17:10:37      4025                 Chris Grosso
# 94 2015-09-24 13:45:40      3725             Jahnavi Harrison
# 95 2015-09-24 13:45:40      3725
# 96 2015-09-17 21:04:54      3756                      Ram Dev
# 97 2015-08-20 18:51:19      3701               Gelek Rimpoche
# 98 2015-08-13 20:18:21      3622               Gogo Gathering
# 99 2015-07-02 17:49:05      3677   Geshe Thupten Jinpa Langri
#
#                                                 title
# 50    Ep. 186 - Getting Ultra Spiritual with JP Sears
# 51               Ep. 185 - Dakota Wint and Koi Fresco
# 52               Ep. 185 - Dakota Wint and Koi Fresco
# 53                           Ep. 184 - Dr. Paul Ekman
# 54          Ep. 181 - "Mensch Up" with Lama Surya Das
# 55            Ep. 180 - Love, Always with Mona Haydar
# 56                             Ep. 179 - Nancy Colier
# 57       Ep. 178 - Inner Excavation with David Silver
# 58  Ep. 177 - One Ground, Two Paths with Lama Tsul...
# 59                                 Ep. 175 - Rob Bell
# 60                  Ep. 174 - Chris "Bash" Bashinelli
# 61              Ep. 173 - Reverend Alexander MacPhail
# 62                                    Ep. 172 - Mooji
# 63  Ep. 171 - Terra Nova with Jared Levy and Marti...
# 64  Ep. 171 - Terra Nova with Jared Levy and Marti...
# 65                           Ep. 170 - Sacred Science
# 66  Ep. 168 – David Nichtern: Awakening from the D...
# 67        Ep. 167 - Bioneers Co-Founder Kenny Ausubel
# 68                          Ep. 166 - Larry Brilliant
# 69               Ep. 165 - Empathy with Judith Orloff
# 70           Ep. 164 - Dan Harmon and Duncan Trussell
# 71           Ep. 164 - Dan Harmon and Duncan Trussell
# 72         Ep. 160 - Buddhist Geeks with Vincent Horn
# 73              Ep. 157 - Trevor Hall and Mother Kali
# 74              Ep. 157 - Trevor Hall and Mother Kali
# 75      Ep. 155 - Failure Free Zone with Gil Fronsdal
# 76                             Ep. 153 - Polarization
# 77  Ep. 152 - Talking Transitions with Frank Ostas...
# 78  Ep. 151 - New Beliefs, New Brain with Lisa Wim...
# 79                               Ep. 150 - Dream Yoga
# 80  Ep. 149 - Koshin Paley Ellison's Contemplative...
# 81        Ep. 148 - Rick Doblin's Psychedelic Studies
# 82        Ep. 146 - Getting Real with Jake Sasseville
# 83          Ep. 145 - James Doty: Into the Magic Shop
# 84          Ep. 141 - Kiley Jon Clark's Street Dharma
# 85               Ep. 140 - Going Deep with Reggie Ray
# 86      Ep. 138 - Animal Wisdom with Dr. Linda Bender
# 87      Ep. 137 - Roadside Assistance with Rabbi Rami
# 88  Ep. 135 - Roshi Joan Halifax & “Negative Capab...
# 89  Ep. 135 - Roshi Joan Halifax & “Negative Capab...
# 90                    Ep. 134 - Seekers and Smugglers
# 91                    Ep. 134 - Seekers and Smugglers
# 92                            Ep. 130 - Jungle Safari
# 93           Ep. 129 - Chris Grosso's Everything Mind
# 94  Ep. 128 - Jahnavi Harrison, “Like A River To t...
# 95  Ep. 128 - Jahnavi Harrison, “Like A River To t...
# 96  Ep. 127 - Ram Dev Explores Deathlessness:  Fro...
# 97                           Ep. 123 - Gelek Rimpoche
# 98                           Ep. 122 - Gogo Gathering
# 99               Ep. 116 - Geshe Thupten Jinpa Langri

# %%
carasantamaria = xml_to_df('rss_files/carasantamaria.xml')
carasantamaria

# %%
econtalk2013 = xml_to_df_desc('rss_files/econtalk2013.xml')
econtalk2006 = xml_to_df_desc('rss_files/econtalk2006.xml')

def clean_econtalk2006(econtalk2006):
        
    date_parser('\s(EST|GMT)$', econtalk2006)
    
    econtalk2006['guests'] = econtalk2006.description.str.extract(r'([\w\s\'\.]+)',expand=True)
    
    guest_split(', ', econtalk2006)
    guest_split(' of', econtalk2006)
    guest_split(' talks', econtalk2006)
    
    guest_split_last('Nobel Laureate ', econtalk2006)
    guest_split_last('syndicated columnist ', econtalk2006)
    guest_split_last('Investigative journalist ', econtalk2006)
    guest_split_last('Author ', econtalk2006)
    guest_split_last('Novelist ', econtalk2006)
    guest_split_last('The legendary ', econtalk2006)
            
    econtalk2006 = econtalk2006[econtalk2006.guests.str.contains('This is the') == False]
    econtalk2006 = econtalk2006[econtalk2006.guests.str.contains('EconTalk host') == False]
    econtalk2006 = econtalk2006[econtalk2006.guests.str.contains('In this bonus') == False]
    
    econtalk2006 = splitDataFrameList(econtalk2006, 'guests', ' and ')

    return econtalk2006

econtalk2006 = clean_econtalk2006(econtalk2006)

econtalk2006

# %% [markdown]
# ## podcasts to download
